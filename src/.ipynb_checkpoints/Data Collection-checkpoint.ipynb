# %% [markdown]
# ## Image colorisation

# %% [markdown]
# From the example projects we choosed the grayscaled image colorization problem. The first step is to research about fellow solutions. After that, we need to collect the data from different sources. In the first approach we will use only one data source: google open image dataset v4, and to shrink a little bit the dataset we want to specialize in one type of label: Skyline. After that we plan to iteratively increase the dataset with more different label, or just change label to something easier, or collect Skyline images from somewhere else. In this notebook we go through step-by-step in the data collection first, below that we are using our own classes which is the aggregated methods which we use first.

# %%
import pandas as pd
import urllib.request
import uuid
from PIL import Image
import requests
from io import BytesIO
import glob
import numpy as np

import data_collector
import image_loader
# Out:
# O:\ProgrammingSoftwares\anaconda3\envs\tensorflow\lib\site-packages\skimage\viewer\__init__.py:6: UserWarning: Viewer requires Qt
#   warn('Viewer requires Qt')

# %% [markdown]
# ## Read in image url data

# %% [markdown]
# We are using the google open image dataset v4, you can download the aggregated image info from here: https://storage.googleapis.com/openimages/web/download.html .
# We need more file:
#     * The file which contains the ImageID and the urls where we can download the real images, this will be the image_id_url DataFrame.
#     * A class description file, which is a switch table between Image label names and their identifiers.
#     * The image label file, where ImageID and LabelId connected. It is separated in each dataset (train,valid,test).
# First load up into the memory the csv-s. We created a sample folder where you can use up the samples to load into the memory the csv way more faster. We aggregated the below steps into two classes, named: DataCollector and ImageLoader.

# %%
image_id_url = pd.read_csv('O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\image_ids_and_rotation.csv',engine='python',sep = ',')

# %%
image_id_url.head()

# %%
image_labels = pd.read_csv('O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\train-annotations-human-imagelabels.csv',engine='python',sep = ',')

# %%
image_validation_labels = pd.read_csv('O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\validation-annotations-human-imagelabels.csv',engine='python',sep = ',')
image_test_labels = pd.read_csv('O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\test-annotations-human-imagelabels.csv',engine='python',sep = ',')

# %% [markdown]
# Summarize the data. From the website you can download one-by-one, but i don't need it separately.

# %%
image_labels = pd.concat( [image_labels,image_validation_labels, image_test_labels],ignore_index=True )
image_labels.head()

# %%
class_description = pd.read_csv('O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\class-descriptions.csv',engine='python',header = None, sep = ',')

# %%
class_description.head()

# %% [markdown]
# I want to choose those files which contains cities. I find its label id and save into (city_label).

# %%
city_label = class_description[class_description[1] == 'Skyline'][0]
city_label = city_label.values[0]

# %% [markdown]
# After that i collect all image id, what label equal to city_label. Confidence is important beause there are pictures in the dataset which label is city, but doesn't contains one.

# %%
city_id_df = image_labels.loc[(image_labels['LabelName'] == city_label) & (image_labels['Confidence'] == 1)]

# %% [markdown]
# I inner join the collected city_id_df with the biggest table: image_id_url (this contains urls and author informations) on ImageID.

# %%
merged_df = image_id_url.merge(city_id_df, on='ImageID', how='inner')

# %% [markdown]
# I would like to use the smallest size of the picture, i don't need the best quality now. I'm filter those rows where the smallest image url column is not empty.

# %%
image_urls = merged_df.loc[pd.notnull(merged_df['Thumbnail300KURL'])]

# %% [markdown]
# Example data from our dataset.

# %%
response = requests.get(image_urls['Thumbnail300KURL'][11])
img = Image.open(BytesIO(response.content))
img.show()

# %% [markdown]
# Check if are there any picture which not jpg

# %%
not_jpg_df = image_urls.loc[image_urls['Thumbnail300KURL'].str.rsplit('.',1).apply(lambda x: 'jpg' not in x[1])]
list(not_jpg_df)

# %% [markdown]
# This is just the Dataframe header row, so there are only jpg url page. The bad reality is that flickr response back a few time an blank image whith "Image no longer exists" with HTTP status code 200, luckily its Content-Type is image/png so i can filter these pictures out.

# %%
image_id_rotation_csv = 'O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\image_ids_and_rotation.csv'
train_annotation_csv = 'O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\train-annotations-human-imagelabels.csv'
validation_annotation_csv = 'O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\validation-annotations-human-imagelabels.csv'
test_annotation_csv = 'O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\test-annotations-human-imagelabels.csv'
class_desc_csv = 'O:\\ProgrammingSoftwares\\anaconda_projects\\dp_nagyhazi\\data\\class-descriptions.csv'

# %%
image_folder = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/data/images/'
data_handler = DataCollector()
data_handler.load_datas(image_id_rotation_csv, train_annotation_csv, validation_annotation_csv, test_annotation_csv, class_desc_csv)
#data_handler.collect_small_images(image_urls, image_folder)

# %%
data_handler.find_by_labelName('Skyline')

# %% [markdown]
# Saving out for sample data.

# %%
train_labl_path = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/train_labels.csv'
valid_labl_path = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/valid_labels.csv'
test_labl_path = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/test_labels.csv'
class_desc_path = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/class_desc.csv'
image_id_path = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/image_ids.csv'

def saving_out_sample():
    train_labl_df = data_handler.labeled_df.sample(50)
    valid_labl_df = data_handler.labeled_df.sample(10)
    test_labl_df = data_handler.labeled_df.sample(40)

    all_labl_df = pd.concat([train_labl_df, valid_labl_df, test_labl_df])

    train_labl_df.to_csv(train_labl_path, index = False)
    valid_labl_df.to_csv(valid_labl_path, index = False)
    test_labl_df.to_csv(test_labl_path, index = False)

    label_id_df = data_handler.class_description[data_handler.class_description[1] == 'Skyline']
    label_id_df.to_csv(class_desc_path , index = False, header = False)


    image_id_labeled = data_handler.image_id_url.merge(pd.DataFrame(all_labl_df['ImageID']), on='ImageID', how='inner')
    image_id_labeled.to_csv(image_id_path, index = False)

# %%
data_hl = data_collector.DataCollector()
data_hl.load_datas(image_id_path, train_labl_path, valid_labl_path, test_labl_path, class_desc_path)
data_hl.find_by_labelName('Skyline')
# Out:
#               ImageID      Subset  \
# 0    0025d1950652e2f8       train
# 1    9aa29d4adc92266e       train
# 2    00a7e199f36d16e7       train
# 4    435d9f47d87d246a       train
# 5    006a2e98a6fc8131       train
# 6    00b518b6f5fa75a3       train
# 7    07dd7409f8c112d8       train
# 8    002c3cfbadaa29c4       train
# 9    0193dccaa8e567f3       train
# 10   5fcd2d022ab18578        test
# 11   009a212ab8033394       train
# 12   002ec3785472ae78       train
# 13   04c3788f162e8bd0       train
# 14   0df2b643bf350da9       train
# 15   00252769f627a383       train
# 16   000c6388be8d67a0       train
# 17   00824f58e6ae733c       train
# 18   11208c94b73b53c8       train
# 19   10896b8c9aaf34cf       train
# 20   011a574fd342ab53       train
# 21   0114fd9055e63b65       train
# 22   2ed133e8f665c7cc  validation
# 23   113803658fe2076b       train
# 24   efe0de6f6f130d94        test
# 25   d4ddcc06cc2b1f9b        test
# 26   784be986eeae58da  validation
# 27   001ca8f5696a5fcd       train
# 28   0aabbd62f968ec15       train
# 29   039268b677ab4f63       train
# 30   0099d4cbcd86d84d       train
# ..                ...         ...
# 68   002054b7ed8ef8c7       train
# 69   005c9cd140c62d2a       train
# 70   0ea0122630dce5da       train
# 71   176df15558354490       train
# 72   4fad54a64e605a3e       train
# 73   692e9e3c290e82f7       train
# 78   00089f491c12d62f       train
# 79   019593419514d93a       train
# 80   00f1161d674398d9       train
# 81   00f1161d674398d9       train
# 82   00f1161d674398d9       train
# 83   00f1161d674398d9       train
# 84   3a6454ca72018dec       train
# 85   0193d3bb86c9d0e0       train
# 86   00402d44c6135333       train
# 87   002f81522d75f8c2       train
# 88   07b02cce161e0406       train
# 89   00004fd8760d4346       train
# 90   04686398c20b3e0a       train
# 91   00b20d09b71be8a3       train
# 92   0f59c94d1478bef9       train
# 93   003362b7e5d50de1       train
# 94   07f71e9fdea3867c       train
# 95   03142c57be3fc9f2       train
# 96   4d3f37c325489e39  validation
# 97   0bba41cfd90ca7a6       train
# 98   da4be9125f1e5462        test
# 99   167dbfb3f850fa73       train
# 100  3b5a3f57ee9b0365        test
# 103  d973115bbf22d5fa  validation
#
#                                            OriginalURL  \
# 0    https://c1.staticflickr.com/8/7020/6739450819_...
# 1    https://c7.staticflickr.com/9/8035/7936013448_...
# 2    https://farm8.staticflickr.com/4078/4807058753...
# 4    https://c3.staticflickr.com/8/7113/7429979384_...
# 5    https://farm2.staticflickr.com/5174/5458928090...
# 6    https://farm4.staticflickr.com/8007/7658826890...
# 7    https://c1.staticflickr.com/6/5102/5561456506_...
# 8    https://farm5.staticflickr.com/3781/2026699714...
# 9    https://farm4.staticflickr.com/669/20351241859...
# 10   https://c1.staticflickr.com/3/2360/1629273674_...
# 11   https://farm5.staticflickr.com/6194/6069230113...
# 12   https://c1.staticflickr.com/8/7282/8713904067_...
# 13   https://farm1.staticflickr.com/7697/1648174363...
# 14   https://c2.staticflickr.com/9/8008/7570743054_...
# 15   https://farm4.staticflickr.com/3568/3349800770...
# 16   https://farm1.staticflickr.com/3219/2880634746...
# 17   https://c5.staticflickr.com/4/3786/10111442256...
# 18   https://c1.staticflickr.com/3/2182/2410126973_...
# 19   https://c8.staticflickr.com/9/8083/8403913644_...
# 20   https://farm4.staticflickr.com/3030/3088045548...
# 21   https://farm6.staticflickr.com/8302/7858959250...
# 22   https://c5.staticflickr.com/6/5476/10572678146...
# 23   https://c4.staticflickr.com/7/6064/6061837622_...
# 24   https://farm5.staticflickr.com/3164/3034830533...
# 25   https://c4.staticflickr.com/8/7282/16433223577...
# 26   https://c3.staticflickr.com/4/3945/15685990882...
# 27   https://c6.staticflickr.com/8/7340/10398461516...
# 28   https://farm6.staticflickr.com/8527/8635634042...
# 29   https://farm4.staticflickr.com/222/469071128_b...
# 30   https://c6.staticflickr.com/4/3044/2646794635_...
# ..                                                 ...
# 68   https://farm8.staticflickr.com/4040/4654465590...
# 69   https://c3.staticflickr.com/7/6087/6138946263_...
# 70   https://c3.staticflickr.com/3/2847/12857772175...
# 71   https://farm1.staticflickr.com/3934/1544711200...
# 72   https://c7.staticflickr.com/6/5513/9710560617_...
# 73   https://farm8.staticflickr.com/8444/7995127321...
# 78   https://c8.staticflickr.com/4/3269/2830188116_...
# 79   https://c3.staticflickr.com/4/3814/9632355252_...
# 80   https://c2.staticflickr.com/4/3023/2551346487_...
# 83             https://www.flickr.com/people/ronalmog/
# 84          https://www.flickr.com/people/eelkedekker/
# 85                https://www.flickr.com/people/akras/
# 86            https://www.flickr.com/people/williamjm/
# 87             https://www.flickr.com/people/blogchef/
# 88     https://www.flickr.com/people/elainerossbaylon/
# 89       https://www.flickr.com/people/davidberkowitz/
# 90         https://www.flickr.com/people/cubanrefugee/
# 91             https://www.flickr.com/people/glynlowe/
# 92     https://www.flickr.com/people/aliciamhernandez/
# 93   https://www.flickr.com/people/cityrunningtours...
# 94                https://www.flickr.com/people/gaspa/
# 95        https://www.flickr.com/people/davebloggs007/
# 96            https://www.flickr.com/people/flissphil/
# 97      https://www.flickr.com/people/minniemouseaunt/
# 98         https://www.flickr.com/people/foreverphoto/
# 99              https://www.flickr.com/people/zengame/
# 100            https://www.flickr.com/people/webseitz/
# 103           https://www.flickr.com/people/hinnosaar/
#
#                              Author  \
# 0                       Daniel Lobo
# 1                        Jon Hanson
# 2                  Johnny Ainsworth
# 4                           Bit Boy
# 5                              vxla
# 6                      Lucas Garcia
# 7                        Tri Nguyen
# 8                        Traveltipy
# 9             South African Tourism
# 10                    Casper Moller
# 11                     Robert Cutts
# 12                 Francisco Anzola
# 13                       Bex Walton
# 14                    Jesse Newland
# 15                        Alperians
# 16                     Fuzzy Gerdes
# 17                            David
# 18                       fotocarios
# 19                           Neil H
# 20                        nevstokes
# 21                           jo.sau
# 22             Dirk VorderstraÃƒÅ¸e
# 23                    Rafael Robles
# 24            Tiago J. G. Fernandes
# 25                       RecoilRick
# 26                         GanMed64
# 27                          GoToVan
# 28                     Marle&#x27;s
# 29                 Kevin Stephenson
# 30                        Ananth BS
# ..                              ...
# 68             Eden, Janine and Jim
# 69                            Jared
# 70                  Patrik Tschudin
# 71                    vagueonthehow
# 72                           jo.sau
# 73                      Alan Levine
# 78    Debs (ÃƒÂ²Ã¢â‚¬Â¿ÃƒÂ³)Ã¢â„¢Âª
# 79                         Lima Pix
# 80                         RonAlmog
# 81                         RonAlmog
# 82                         RonAlmog
# 83                         RonAlmog
# 84                            Eelke
# 85                           Andrey
# 86                  William Marnoch
# 87           Urban Explorer Hamburg
# 88               elaine ross baylon
# 89                  David Berkowitz
# 90                   Yovany Camacho
# 91                 www.GlynLowe.com
# 92                       Alicia0928
# 93                   Marlin Keesler
# 94             Francesco Gasparetti
# 95   Thank you for visiting my page
# 96                   Phillip Capper
# 97                  minniemouseaunt
# 98                          KellyB.
# 99                          Zengame
# 100                      Bill Seitz
# 103    Marit &amp; Toomas Hinnosaar
#
#                                                  Title  OriginalSize  \
# 0                               Paseo de la Castellana        576901
# 1                         View from the Bund. Shanghai        334842
# 2                                             DSC_0751       1238018
# 4                              SF From Alcatraz Island       2112997
# 5                    South Branch of the Chicago River       9048576
# 6                          Alphaville e Vila Boa Vista        543461
# 7              Ã„ï¿½Ã¡ÂºÂ³ng cÃ¡ÂºÂ¥p sÃ¡Â»â€˜ng ...?!        594971
# 8    KoÃ…Â¡ice - district on the lake called Nad Ja...       5056689
# 9               Bloemfontein, Free State, South Africa      11269427
# 10                                        IMG_0126.jpg        837534
# 11              Birkenhead seen from across the Mersey        413827
# 12                                   Dubai skyscrapers       6281824
# 13                                     Lower Manhattan       1828339
# 14                                            Untitled       5104996
# 15                                            IMG_1575       4166518
# 16                                             Chicago       2873517
# 17                                            _MG_5699       7349688
# 18                       RSRÃ¤Â¼Å¡Ã¥Â Â´Ã£ï¿½Â«Ã£ï¿½Â¦        147711
# 19                                            Untitled       1164685
# 20                                 From Jacob's Ladder       5084259
# 21                                           Singapore        465652
# 22   RWE-Kraftwerksneubau in Hamm-Uentrop vom Haars...        557465
# 23        Vista de TeherÃƒÂ¡n desde los montes Alburtz       2705416
# 24                                    Monte Alentejano        339553
# 25                          Downtown Nashville, winter        515077
# 26                               Rugeley Power Station       2101801
# 27                                        Stanley Park       5486612
# 28                                            IMG_5146       1075995
# 29                              Sears Tower - Downtown       1087922
# 30                                            IMG_4663       1609819
# ..                                                 ...           ...
# 68                               The Coast of Brooklyn       2797766
# 69   Tampa - Ballast Point Park - Downtown Tampa Sk...       1371013
# 70                            Stadtrandentwicklung Ost         92717
# 71                                     Top of the Rock       9099929
# 72                                           Guangzhou        328886
# 73                                     Sailing Toronto       3625425
# 78                                           Kokura-jo       1048416
# 79                                       Oh ManÃ¢â‚¬Â¦        408945
# 80                            Israel-Carmel-050508 024       1971577
# 81                            Israel-Carmel-050508 024       1971577
# 82                            Israel-Carmel-050508 024       1971577
# 83                            Israel-Carmel-050508 024       1971577
# 84                          Atmosys-final (0.01.43.08)        511760
# 85   Ã�Â£Ã‘â€šÃ‘â‚¬Ã�ÂµÃ�Â½Ã�Â½Ã‘ï¿½Ã‘ï¿½ Ã�Å“Ã�Â¾Ã...        803462
# 86                                      London Bridges        147827
# 87           Food Trucks Festival Spielbudenplatz 2015       7149713
# 88                               overlooking han river       3495338
# 89     Panoramic View - Quito, Ecuador - South America       5033495
# 90                            Lunar Eclipse Night 4/15       4324065
# 91           The New York Water Taxi - New Jersey City        428714
# 92                                          IMG_0220_1       1556781
# 93                     Instant gratification 5k Finish       3608211
# 94          Gerusalemme: al aqsa e cupola della roccia       1771233
# 95                               A walk around Calgary         83733
# 96         Cold and miserable, Wellington 15 June 2005       2098950
# 97                                      Split harbour.        306195
# 98                                      SacrÃƒÂ© Coeur        460227
# 99                                            IMG_0112       2709998
# 100                               2001-09-11-no-towers         32683
# 103           Fountains of Bellagio, God Bless the USA        140541
#
#                   OriginalMD5  \
# 0    7umWEIMPz8KoTG4uJmSs4w==
# 1    tp9jffm8L4cfWSChjxmIpw==
# 2    ErlONqjedGVyawjNt7e7ow==
# 4    3Evaflm5W2bpfeeSjC0HjA==
# 5    yMIl/a+M3+J3vYVtvdSKkw==
# 6    nfRO2P+DNm52AMWt1RmivQ==
# 7    U+qEPwLW62+qJ85AgAxt2Q==
# 8    zzeYLkrK05/g65tv3VpPYg==
# 9    aryqmGsKRRXuNRzoaNW0Pg==
# 10   Lab/RAHGZ9zwA5qg1236DQ==
# 11   /SWpOYnzjqlLpDSvc4F8MA==
# 12   tyJ09MTJ0hZEUML87FWJEA==
# 13   rvWcZu46x3mTaESYwZrqdA==
# 97   https://c6.staticflickr.com/3/2747/4277720330_...       0.0
# 98   https://c1.staticflickr.com/1/111/302327991_80...       0.0
# 99   https://c4.staticflickr.com/8/7629/16936332859...       0.0
# 100  https://c7.staticflickr.com/1/1/577035_75113a0...       0.0
# 103  https://c3.staticflickr.com/3/2471/3933757897_...       NaN
#
#                        Source  LabelName  Confidence
# 0                verification  /m/0204fg           1
# 1                verification  /m/0204fg           1
# 2                verification  /m/0204fg           1
# 4                verification  /m/0204fg           1
# 5                verification  /m/0204fg           1
# 6                verification  /m/0204fg           1
# 7                verification  /m/0204fg           1
# 8                verification  /m/0204fg           1
# 9    crowdsource-verification  /m/0204fg           1
# 10               verification  /m/0204fg           1
# 11               verification  /m/0204fg           1
# 12               verification  /m/0204fg           1
# 13               verification  /m/0204fg           1
# 14   crowdsource-verification  /m/0204fg           1
# 15               verification  /m/0204fg           1
# 16               verification  /m/0204fg           1
# 17               verification  /m/0204fg           1
# 18   crowdsource-verification  /m/0204fg           1
# 19   crowdsource-verification  /m/0204fg           1
# 20               verification  /m/0204fg           1
# 21               verification  /m/0204fg           1
# 22               verification  /m/0204fg           1
# 23   crowdsource-verification  /m/0204fg           1
# 24               verification  /m/0204fg           1
# 25   crowdsource-verification  /m/0204fg           1
# 26               verification  /m/0204fg           1
# 27               verification  /m/0204fg           1
# 28               verification  /m/0204fg           1
# 29               verification  /m/0204fg           1
# 30               verification  /m/0204fg           1
# ..                        ...        ...         ...
# 68               verification  /m/0204fg           1
# 69               verification  /m/0204fg           1
# 70               verification  /m/0204fg           1
# 71               verification  /m/0204fg           1
# 72               verification  /m/0204fg           1
# 73               verification  /m/0204fg           1
# 78               verification  /m/0204fg           1
# 79               verification  /m/0204fg           1
# 80               verification  /m/0204fg           1
# 81               verification  /m/0204fg           1
# 82               verification  /m/0204fg           1
# 83               verification  /m/0204fg           1
# 84               verification  /m/0204fg           1
# 85               verification  /m/0204fg           1
# 86               verification  /m/0204fg           1
# 87               verification  /m/0204fg           1
# 88   crowdsource-verification  /m/0204fg           1
# 89               verification  /m/0204fg           1
# 90               verification  /m/0204fg           1
# 91               verification  /m/0204fg           1
# 92   crowdsource-verification  /m/0204fg           1
# 93               verification  /m/0204fg           1
# 94   crowdsource-verification  /m/0204fg           1
# 95               verification  /m/0204fg           1
# 96   crowdsource-verification  /m/0204fg           1
# 97   crowdsource-verification  /m/0204fg           1
# 98               verification  /m/0204fg           1
# 99   crowdsource-verification  /m/0204fg           1
# 100              verification  /m/0204fg           1
# 103              verification  /m/0204fg           1
#
# [97 rows x 15 columns]

# %%
image_folder = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/images/'
data_hl.collect_small_images(data_hl.result_label_df , image_folder)

# %%
image_folder = 'O:/ProgrammingSoftwares/anaconda_projects/dp_nagyhazi/samples/images/'
img_loader = image_loader.ImageLoader(image_folder)
img_loader.separate_small_data(0.1,0.1)
# Out:
# O:\ProgrammingSoftwares\anaconda3\envs\tensorflow\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# O:\ProgrammingSoftwares\anaconda3\envs\tensorflow\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
from matplotlib.pyplot import imshow
from skimage import color
# %matplotlib inline

imshow(color.lab2rgb(img_loader.dataset[3]))
